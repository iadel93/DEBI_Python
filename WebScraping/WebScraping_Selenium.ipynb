# %% [markdown]
# Selenium

# %%
# !pip install selenium

# %%
from selenium import webdriver
browser = webdriver.Chrome()

browser.get('http://google.com')
print(browser.title)
browser.close()
# Out:
# Google

# %% [markdown]
# Find

# %%
# find by Name

from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.example.com/')
# print(browser.title)
data = browser.find_elements(By.TAG_NAME,"h1")
for e in data:
    print("*****")
    print(e.text)
browser.close()
# Out:
# *****
# Example Domain

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.example.com/')
# print(browser.title)
data = browser.find_elements(By.TAG_NAME,"p")
for e in data:
    print("*****")
    print(e.text)
browser.close()
# Out:
# *****
# <selenium.webdriver.remote.webelement.WebElement (session="c52b50039c235fc05ab504aab87c7c47", element="f.5DB7B603AC27B9573BF54F6170F30D49.d.3CE19C2798A23B47CC286DDBEB088102.e.2")>
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# *****
# <selenium.webdriver.remote.webelement.WebElement (session="c52b50039c235fc05ab504aab87c7c47", element="f.5DB7B603AC27B9573BF54F6170F30D49.d.3CE19C2798A23B47CC286DDBEB088102.e.3")>
# More information...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.google.com/')
# print(browser.title)
data = browser.find_elements(By.TAG_NAME,"div")
for e in data:
    print("*****")
    print(e.text)
browser.close()
# Out:
# *****
# Gmailصور
# تسجيل الدخول
# محرّك بحث Google متوفّر باللغة: English
# مصر
# لمحة
# الإعلانات
# الأعمال
# آلية عمل "بحث Google"
# العقد الثالث من نشاطنا في مجال المناخ: تحقق من عملنا
# الخصوصية
# البنود
# الإعدادات
# *****
# Gmailصور
# تسجيل الدخول
# *****
# Gmailصور
# تسجيل الدخول
# *****
# Gmailصور
# تسجيل الدخول
# *****
# Gmailصور
# تسجيل الدخول
# *****
# Gmailصور
# تسجيل الدخول
# *****
# Gmailصور
# *****
# Gmailصور
# *****
# Gmail
# *****
# صور
# *****
# تسجيل الدخول
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# *****
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.amazon.eg/deals?ref_=nav_cs_gb')
# print(browser.title)
data = browser.find_elements(By.CLASS_NAME,"a-truncate-cut")
for e in data:
    print("*****")
    print(e.text)
browser.close()
# Out:
# *****
# سماعات اذن لاسلكية ساوند كور a3991h11 من انكر لايف بي 2 اي…
# *****
# حذاء رياضي كاي واير رجالي من مينترا
# *****
# adidas mens RACER TR23 Running shoes
# *****
# طارة دركسيون للألعاب V99 من بي اكس ان، بدوران 270/900 درجة و…
# *****
# الة حاسبة رقمية من كاسيو FX-991ESPLUS-2WDTV - اسود
# *****
# قميص كلاسيكي للرجال من وايت ايجل
# *****
# فوطة حمام للفنادق من قطن مصري 100% كيوبيد (أخضر (كاكي)، 90…
# *****
# مزيل وبر كهربائي قابل لاعادة الشحن من الملابس من سوكاني، ازرق SK-866

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.amazon.eg/s?k=phone&crid=1V6OCP1NT6ELV&sprefix=phone%2Caps%2C141&ref=nb_sb_noss_1')
# print(browser.title)
price = browser.find_elements(By.CLASS_NAME,"a-price-whole")
product = browser.find_elements(By.CLASS_NAME,"a-size-base-plus")
for pr,prod in zip(price,product):
    print("*****")
    print(prod.text)
    print(pr.text)
# browser.close()
# Out:
# *****
# ابل موبايل ايفون 16 برو ماكس بشريحتين (256 جيجابايت) - ديزرت تيتانيوم
# 70,799
# *****
# موبايل ذكي A70 من ايتيل بذاكرة رام 3 جيجابايت - ROM 64 ذهبي إصدار محلي ايه 70
# 3,149
# *****
# هاتف ذكي ريدمي A3 بذاكرة RAM 3GB - تخزين 64GB وشاشة 6.71 انش HD+ 90Hz وبطارية 5000mAh وشريحتين اتصال وكاميرا مزدوجة واتصال 4G لتجربة جوال قوية وانيقة، اسود
# 3,899
# *****
# نوكيا 105 تي إيه - 1557 دي إس نينا 1 فحمي، بشريحتين
# 699
# *****
# موبايل ذكي ايتيل A70 بذاكرة رام 3 جيجابايت - ROM 64 أزرق - إصدار محلي ايه 70
# 3,149
# *****
# موبايل انفنيكس سمارت 9 رام: 4+4GB ذاكرة ROM: 128GB 6.7 بوصة HD+ كاميرا خلفية مزدوجة 13MP بالذكاء الاصطناعي مع فلاش وأمامية 8MP بطارية 5000 mAh شريحة اتصال نانو نوع سي اندرويد 14 نيو
# 4,399
# *****
# شاومي ريدمي A3، ذاكرة RAM 4GB | روم 128GB، شاشة 6.71 انش HD+ 90 هرتز، بطارية 5000mAH، شريحتي اتصال، كاميرا مزدوجة، (4G) اسود، ضمان محلي لمدة عام
# 4,676
# *****
# ...

# %%
# Locating by XPATH
from selenium import webdriver
from selenium.webdriver.common.by import By
browser = webdriver.Chrome()

browser.get('https://www.amazon.eg/s?k=phone&crid=1V6OCP1NT6ELV&sprefix=phone%2Caps%2C141&ref=nb_sb_noss_1')
# print(browser.title)
price = browser.find_elements(By.XPATH,"//span[@class='a-price-whole']")
product = browser.find_elements(By.XPATH,"//a/h2/span")
print(price)
# print(product)
for pr,prod in zip(price,product):
# for prod in product:
    print("*****")
    # print(prod.text)
    print(prod.text)
    print(pr.text)
# for pr in price:
#     print("*****")
#     # print(prod.text)
#     print(pr.text)
browser.close()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6091877273", element="f.6F3D17DD9E993B606EB60B4366856C51.d.F6B74AE859573C882CD1B0AACF330432.e.257")>, <selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6091877273", element="f.6F3D17DD9E993B606EB60B4366856C51.d.F6B74AE859573C882CD1B0AACF330432.e.258")>, <selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6091877273", element="f.6F3D17DD9E993B606EB60B4366856C51.d.F6B74AE859573C882CD1B0AACF330432.e.259")>, <selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6091877273", element="f.6F3D17DD9E993B606EB60B4366856C51.d.F6B74AE859573C882CD1B0AACF330432.e.260")>, <selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6091877273", element="f.6F3D17DD9E993B606EB60B4366856C51.d.F6B74AE859573C882CD1B0AACF330432.e.261")>, <selenium.webdriver.remote.webelement.WebElement (session="40181ea3e4c2c251e0fc0c6
# ...

# %% [markdown]
# Interacting

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

browser = webdriver.Chrome()

browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,"textarea")
search_bar.send_keys("Python",Keys.ENTER)
time.sleep(3)
browser.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 

browser = webdriver.Chrome()

browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,"textarea")
search_bar.send_keys("Python",Keys.ENTER)
time.sleep(3)

links = browser.find_elements(By.XPATH,"//h3")
for link in links:
    print(link.text)
# next = browser.find_element(By.XPATH, "//span[@class='oeN89d']/span[@dir='rtl']")
# if next:
#     next.click()
# browser.close()
# Out:
# Welcome to Python.org
# Downloads
# Python Releases for Windows
# Python 3.13.0
# Python For Beginners
# Documentation
# Python Tutorial
# Python (programming language)
# Online Python - IDE, Editor, Compiler, Interpreter
#
#
#
#
# Introduction to Python
# Online Python Compiler (Interpreter)
# Python Courses & Tutorials

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd

browser = webdriver.Chrome()

browser.get('https://www.google.com/')
search_bar = browser.find_element(By.TAG_NAME,"textarea")
search_bar.send_keys("Amazon eg",Keys.ENTER)
browser.implicitly_wait(5)
links = browser.find_elements(By.XPATH,"//span[@dir='ltr']")
for link in links:
    print(link.text)
next = browser.find_element(By.XPATH, "//span[@class='oeN89d']/span[@dir='rtl']")
# if next:
#     next.click()
# browser.close()

data = pd.DataFrame({"Link":[link.text for link in links]})
print(data.head())
data.to_csv("amazon_links.csv")
# Out:
# amazon.eg
# https://www.amazon.eg
# amazon+com
#
#
#
# amazon.eg
# Amazon.com. Spend less. Smile more.
# Amazon.com
# https://www.amazon.com
#
#
# Free shipping on millions of items. Get the best of Shopping and Entertainment with Prime. Enjoy low prices and great deals on the largest selection of ...
# Amazon Prime
# If you haven't been an Amazon Prime member in the last 12 ...
# Books
# Online shopping from a great selection at Books Store.
# Amazon
# Free shipping on millions of items. Get the best of Shopping and ...
# Prime Video
# Watch now on Prime Video for a wide selection of movies, TV ...
# Deals
# Can't miss offers · Stocking stuffersStocking stuffers · 10 ...
# amazon.com
#                     Link
# 0              amazon.eg
# 1  https://www.amazon.eg
# 2             amazon+com
# 3
# 4

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

browser = Chrome()
browser.get("https://www.google.com")
search_bar = browser.find_element(By.CLASS_NAME,"gLFyf")
search_bar.send_keys("Python",Keys.ENTER)
# browser.implicitly_wait(5)
time.sleep(3)

headers = browser.find_elements(By.XPATH, "//h3")
for h in headers:
    print(h.text)

next_page = browser.find_element(By.XPATH,"//span[@class='oeN89d']")
while True:
    if next_page:
        next_page.click()
        time.sleep(3)
        headers = browser.find_elements(By.XPATH, "//h3")
        for h in headers:
            print(h.text)
    else:
        break

    next_page = browser.find_elements(By.XPATH,"//span[@class='oeN89d']")[-1]

browser.close()
# Out:
# Welcome to Python.org
# Downloads
# Python Releases for Windows
# Python 3.13.0
# Python For Beginners
# Documentation
# Python Tutorial
# Python (programming language)
# Online Python - IDE, Editor, Compiler, Interpreter
#
#
#
#
# Introduction to Python
# Online Python Compiler (Interpreter)
# Python Courses & Tutorials
# Python for Everybody Specialization (Michigan)
# The Complete Python Bootcamp From Zero to Hero in Python
# python - Official Image
# r/Python
# Python - Visual Studio Marketplace
# بايثون (لغة برمجة)
# PythonAnywhere: Host, run, and code Python in the cloud
# Welcome To Colab - Colab
# Python Essentials 1
# Learn Python
# Python
# Solve Python
# Learn Python 2
# Python for beginners - Training
# Google's Python Class | Python Education
# Python Full Course for Beginners
# Learn to become a modern Python developer
# pandas - Python Data Analysis Library
# Download Anaconda Distribution
# Introduction to Python Course
# Introduction to Python Course
# ...

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

browser = Chrome()
browser.get("https://www.google.com")
search_bar = browser.find_element(By.CLASS_NAME,"gLFyf")
search_bar.send_keys("Python",Keys.ENTER)
# browser.implicitly_wait(5)
time.sleep(3)
images_button = browser.find_elements(By.XPATH,"/html/body/div[3]/div/div[3]/div/div/div/div/div/div/div[1]/div/div[2]/a")[0]
# print(images_button)
images_button.click()
time.sleep(1)
images = browser.find_elements(By.XPATH,"//div/g-img/img")

for img in images:
    print(img.get_attribute("src"))
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUd7hpototV7pjxvrrBXF7Nq7fcquUParD3YvcPWG02TAia0aVlrwuci5yNmk&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTs3iJ43kdr_viNOkOXlR30dK08OpljUY2n7Vzd0c4D7bwNOcfD5H1GK3-V1LM&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcREfKwoDcqLn6hmJtop0QdV4Zg5sgijKiXTZcVIab4dFcMrZuhcvzBbo6SlBK0&s
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# ...:image/gif;base64,R0lGODlhAQABAIAAAP///////yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# ...:image/png;base64,...
# ...:image/jpeg;base64,...
# ...:image/jpeg;base64,...
# ...:image/png;base64,...
# ...:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
import os

def download_images(search_query, num_images):
    # Set up the Chrome WebDriver
    options = webdriver.ChromeOptions()
    # options.add_argument('--headless')  # Run in headless mode (no GUI)
    driver = webdriver.Chrome(options=options)

    # Create a directory to save images
    if not os.path.exists(search_query):
        os.makedirs(search_query)

    # Construct the search URL and navigate to it
    search_url = f"https://www.google.com/search?hl=en&tbm=isch&q={search_query}"
    driver.get(search_url)

    # Wait for images to load
    time.sleep(2)

    # Find image elements on the page
    image_elements = driver.find_elements(By.CLASS_NAME, 'rg_i')
    print(image_elements)
    count = 0
    for img in image_elements:
        try:
            img.click()  # Click on the thumbnail to open the full image
            time.sleep(1)  # Wait for the full image to load
            
            # Locate the full-size image element and get its URL
            full_img_element = driver.find_element(By.CLASS_NAME, 'n3VNCb')
            img_url = full_img_element.get_attribute("src")

            # Download the image if it's a valid URL
            if img_url.startswith('http'):
                response = requests.get(img_url)
                if response.status_code == 200:
                    with open(os.path.join(search_query, f'image_{count + 1}.jpg'), 'wb') as file:
                        file.write(response.content)
                        count += 1

            # Stop after downloading the specified number of images
            if count >= num_images:
                break

        except Exception as e:
            print(f"An error occurred: {e}")

    driver.quit()  # Close the browser

# Example usage: Download 5 images of "cats"
download_images("cats", 5)
# Out:
# []

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By

driver = Chrome()
driver.get("https:example.com")
data = driver.find_element(By.XPATH,"//div/p[1]")
print(data.text)
# Out:
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
